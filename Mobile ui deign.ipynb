# %%
# Install Hugging Face datasets and transformers
# !pip install datasets transformers

# Install PyTorch (for working with models later)
# !pip install torch

# Optionally install TensorFlow (if you prefer working with it)
# !pip install tensorflow
# Out:
# Collecting datasets
#   Downloading datasets-3.0.1-py3-none-any.whl (471 kB)
#      -------------------------------------- 471.6/471.6 kB 3.0 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.45.2-py3-none-any.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\91805\anaconda3\lib\site-packages (from datasets) (1.4.4)
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-17.0.0-cp39-cp39-win_amd64.whl (25.1 MB)
#      ---------------------------------------- 25.1/25.1 MB 2.9 MB/s eta 0:00:00
# Collecting fsspec[http]<=2024.6.1,>=2023.1.0
#   Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      ------------------------------------- 177.6/177.6 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\91805\anaconda3\lib\site-packages (from datasets) (21.3)
# Collecting requests>=2.32.2
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in c:\users\91805\anaconda3\lib\site-packages (from datasets) (6.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.17-py39-none-any.whl (133 kB)
#      -------------------------------------- 133.4/133.4 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\91805\anaconda3\lib\site-packages (from datasets) (1.24.3)
# Collecting tqdm>=4.66.3
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.4/78.4 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\91805\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\91805\anaconda3\lib\site-packages (from datasets) (0.3.4)
# Collecting aiohttp
#   Downloading aiohttp-3.10.9-cp39-cp39-win_amd64.whl (382 kB)
#      -------------------------------------- 382.2/382.2 kB 7.9 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.5.0-cp39-cp39-win_amd64.whl (30 kB)
# Collecting huggingface-hub>=0.22.0
#   Downloading huggingface_hub-0.25.2-py3-none-any.whl (436 kB)
#      -------------------------------------- 436.6/436.6 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in c:\users\91805\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Collecting tokenizers<0.21,>=0.20
#   Downloading tokenizers-0.20.1-cp39-none-win_amd64.whl (2.4 MB)
#      ---------------------------------------- 2.4/2.4 MB 4.3 MB/s eta 0:00:00
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.5-cp39-none-win_amd64.whl (286 kB)
#      -------------------------------------- 286.1/286.1 kB 2.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\91805\anaconda3\lib\site-packages (from aiohttp->datasets) (23.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.1.0-cp39-cp39-win_amd64.whl (28 kB)
# Collecting yarl<2.0,>=1.12.0
#   Downloading yarl-1.14.0-cp39-cp39-win_amd64.whl (84 kB)
#      ---------------------------------------- 84.1/84.1 kB 2.3 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.1-cp39-cp39-win_amd64.whl (50 kB)
#      ---------------------------------------- 50.7/50.7 kB ? eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\91805\anaconda3\lib\site-packages (from huggingface-hub>=0.22.0->datasets) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\91805\anaconda3\lib\site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91805\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91805\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91805\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2022.9.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91805\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: colorama in c:\users\91805\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Collecting multiprocess
#   Downloading multiprocess-0.70.16-py39-none-any.whl (133 kB)
#      -------------------------------------- 133.4/133.4 kB 7.7 MB/s eta 0:00:00
# Collecting dill<0.3.9,>=0.3.0
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      -------------------------------------- 116.3/116.3 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\91805\anaconda3\lib\site-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\91805\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\91805\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.0-cp39-cp39-win_amd64.whl (45 kB)
#      ---------------------------------------- 45.6/45.6 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, tqdm, safetensors, requests, pyarrow, propcache, multidict, fsspec, frozenlist, dill, async-timeout, aiohappyeyeballs, yarl, multiprocess, huggingface-hub, aiosignal, tokenizers, aiohttp, transformers, datasets
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 12.0.1
#     Uninstalling pyarrow-12.0.1:
#       Successfully uninstalled pyarrow-12.0.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.7.1
#     Uninstalling fsspec-2022.7.1:
#       Successfully uninstalled fsspec-2022.7.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
# Successfully installed aiohappyeyeballs-2.4.3 aiohttp-3.10.9 aiosignal-1.3.1 async-timeout-4.0.3 datasets-3.0.1 dill-0.3.8 frozenlist-1.4.1 fsspec-2024.6.1 huggingface-hub-0.25.2 multidict-6.1.0 multiprocess-0.70.16 propcache-0.2.0 pyarrow-17.0.0 requests-2.32.3 safetensors-0.4.5 tokenizers-0.20.1 tqdm-4.66.5 transformers-4.45.2 xxhash-3.5.0 yarl-1.14.0
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
# conda-repo-cli 1.0.20 requires requests==2.28.1, but you have requests 2.32.3 which is incompatible.
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# Collecting torch
#   Downloading torch-2.4.1-cp39-cp39-win_amd64.whl (199.3 MB)
#      -------------------------------------- 199.3/199.3 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\91805\anaconda3\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: filelock in c:\users\91805\anaconda3\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: networkx in c:\users\91805\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: fsspec in c:\users\91805\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy in c:\users\91805\anaconda3\lib\site-packages (from torch) (1.10.1)
# Requirement already satisfied: jinja2 in c:\users\91805\anaconda3\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\91805\anaconda3\lib\site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\91805\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)
# Installing collected packages: torch
# Successfully installed torch-2.4.1
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# Requirement already satisfied: tensorflow in c:\users\91805\anaconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.56.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.23.4)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Collecting typing-extensions<4.6.0,>=3.6.6
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: setuptools in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (63.4.1)
# Requirement already satisfied: packaging in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (21.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\91805\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\91805\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\91805\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\91805\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.32.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\91805\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\91805\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\91805\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.13.0->tensorflow) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\91805\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\91805\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in c:\users\91805\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.11)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\91805\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\91805\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91805\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91805\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91805\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\91805\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\91805\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# Successfully installed typing-extensions-4.5.0
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.4.1 requires typing-extensions>=4.8.0, but you have typing-extensions 4.5.0 which is incompatible.
# selenium 4.23.0 requires typing_extensions~=4.9.0, but you have typing-extensions 4.5.0 which is incompatible.
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)

# %%
# !pip install diffusers
# Out:
# Collecting diffusers
#   Downloading diffusers-0.30.3-py3-none-any.whl (2.7 MB)
#      ---------------------------------------- 2.7/2.7 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\91805\anaconda3\lib\site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: huggingface-hub>=0.23.2 in c:\users\91805\anaconda3\lib\site-packages (from diffusers) (0.25.2)
# Requirement already satisfied: importlib-metadata in c:\users\91805\anaconda3\lib\site-packages (from diffusers) (4.11.3)
# Requirement already satisfied: filelock in c:\users\91805\anaconda3\lib\site-packages (from diffusers) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\91805\anaconda3\lib\site-packages (from diffusers) (2022.7.9)
# Requirement already satisfied: Pillow in c:\users\91805\anaconda3\lib\site-packages (from diffusers) (9.2.0)
# Requirement already satisfied: numpy in c:\users\91805\anaconda3\lib\site-packages (from diffusers) (1.24.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\91805\anaconda3\lib\site-packages (from diffusers) (0.4.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\91805\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.66.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\91805\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\91805\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.5.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\91805\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\91805\anaconda3\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (21.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\91805\anaconda3\lib\site-packages (from importlib-metadata->diffusers) (3.8.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91805\anaconda3\lib\site-packages (from requests->diffusers) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91805\anaconda3\lib\site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91805\anaconda3\lib\site-packages (from requests->diffusers) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91805\anaconda3\lib\site-packages (from requests->diffusers) (2022.9.14)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\91805\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.23.2->diffusers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\91805\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.2->diffusers) (0.4.6)
# Installing collected packages: diffusers
# Successfully installed diffusers-0.30.3
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91805\anaconda3\lib\site-packages)

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from diffusers import StableDiffusionPipeline
import torch
from PIL import Image
from IPython.display import display

# %% [markdown]
# ## Step 1:- Initialize Models

# %%
def initialize_models():
    """Initialize GPT-2 and Stable Diffusion models with error handling."""
    try:
        # Load GPT-2 tokenizer and model
        tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
        model = GPT2LMHeadModel.from_pretrained("gpt2")

        # Load Stable Diffusion model
        pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")

        # Check for GPU availability and move the model to the appropriate device
        if torch.cuda.is_available():
            pipe.to("cuda")
            print("Using GPU for image generation.")
        else:
            pipe.to("cpu")
            print("Using CPU for image generation.")

        print("Models loaded successfully.")
        return tokenizer, model, pipe

    except Exception as e:
        print(f"Error loading models: {e}")
        return None, None, None

# %% [markdown]
# ## Initialize the models

# %%
tokenizer, model, pipe = initialize_models()
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# C:\Users\91805\anaconda3\lib\site-packages\huggingface_hub\file_download.py:147: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\91805\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# C:\Users\91805\anaconda3\lib\site-packages\huggingface_hub\file_download.py:147: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\91805\.cache\huggingface\hub\models--CompVis--stable-diffusion-v1-4. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# safety_checker/config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# (…)kpoints/scheduler_config-checkpoint.json:   0%|          | 0.00/209 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Using CPU for image generation.
# Models loaded successfully.

# %% [markdown]
# ## Step 2: Generate Prompts Using GPT-2

# %%
def generate_prompt(user_input):
    """Generate a prompt based on user input using GPT-2."""
    prompt = f"Create a mobile UI design for: {user_input}"

    # Tokenize input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Generate output prompt from GPT-2
    outputs = model.generate(inputs, max_length=50, num_return_sequences=1)

    # Decode the generated output into text
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return generated_text

# %% [markdown]
# ## Step 3: Validate User Input

# %%
def validate_input(user_input):
    """Check if user input is valid (not empty)."""
    if not user_input or len(user_input.strip()) == 0:
        print("Please enter a valid description.")
        return False
    return True

# %% [markdown]
# ## Step 4: Generate UI Design Image

# %%
def generate_ui_design(user_input, guidance_scale=7.5, num_inference_steps=50):
    """Generate a UI design image using Stable Diffusion."""
    # Validate input
    if not validate_input(user_input):
        return

    # Generate a prompt from the user input
    prompt = generate_prompt(user_input)
    print("Generated Prompt:", prompt)

    # Generate the image based on the prompt
    image = pipe(prompt, guidance_scale=guidance_scale, num_inference_steps=num_inference_steps).images[0]

    # Save and display the generated image
    image.save("generated_ui_design.png")
    display(image)
    print("Image saved as 'generated_ui_design.png'")

# %% [markdown]
# ## Step 5: Main Function for User Interaction

# %%
def main():
    """Main function to run the Mobile UI Design Generator."""
    print("Welcome to the Mobile UI Design Generator!")

    while True:
        # Get user input for the UI design description
        user_input = input("Enter a description for the mobile UI design (or type 'exit' to quit): ")

        # Exit the program if the user types 'exit'
        if user_input.lower() == 'exit':
            print("Exiting the application.")
            break

        # Generate and display the UI design based on user input
        generate_ui_design(user_input)

# Entry point of the program
if __name__ == "__main__":
    main()
# Out:
# Welcome to the Mobile UI Design Generator!
# Enter a description for the mobile UI design (or type 'exit' to quit): a weather application with colorful icons and graphs
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Generated Prompt: Create a mobile UI design for: a weather application with colorful icons and graphs, a weather app with a grid of weather data, a weather app with a grid of weather data, a weather app with a grid of weather data, a weather app with
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# Image saved as 'generated_ui_design.png'
# Enter a description for the mobile UI design (or type 'exit' to quit): exit
# Exiting the application.
